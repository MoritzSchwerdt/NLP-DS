# %%
# %%capture
# !pip install transformers
# !pip install torch
# !pip install json

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM, pipeline
import torch
import json
import os

# %%
def load_model_and_tokenizer(model_name):
    """
    Lade Modell.

    Args:
    model_name (str): Der Name des Modells, das geladen werden soll.

    Returns:
    tokenizer: Der geladene Tokenizer.
    model: Das geladene Modell.
    """
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForMaskedLM.from_pretrained(model_name)
    return tokenizer, model

def load_data(file_path):
    """
    Laden von JSON Lines Daten aus der gegebenen Datei.

    Args:
    file_path (str): Der Pfad zur Datei, die geladen werden soll.

    Returns:
    data: Die geladenen Daten.
    """
    data = []
    with open(file_path, "r") as f:
        for line in f:
            data.append(json.loads(line))
    return data


def predict_masked_token(model, tokenizer, sentence, options):
    """
    Berechne wahrscheinlichstes Token, dass die Mask passt

    Args:
    model: Das model, dass zur Berechnung verwendet wird
    tokenizer: Der Tokenizer der zum Berechnen wird
    sentence (str): der satz mit der Maske
    options (list): die Liste mit Einsetzungsoptionen

    Returns:
    predicted_option (str): die berechnete Option
    """
    # Encode the sentence and options
    inputs = tokenizer.encode_plus(sentence, return_tensors='pt', padding='max_length', max_length=20)
    option_ids = tokenizer.convert_tokens_to_ids(options)

    # Get the id of the masked token
    mask_id = tokenizer.convert_tokens_to_ids(tokenizer.mask_token)

    # Feed the input to the model
    outputs = model(**inputs)
    logits = outputs.logits
    mask_index = inputs['input_ids'][0].tolist().index(mask_id)
    mask_logits = logits[0, mask_index, :]

    # Find the most probable option
    probs = torch.nn.functional.softmax(mask_logits, dim=0)
    option_probs = probs[option_ids]
    max_prob_index = torch.argmax(option_probs).item()
    predicted_option = options[max_prob_index]

    return predicted_option

def evaluate_model(data, tokenizer, model):
    """
    Evaluieren Sie das Modell auf den gegebenen Daten.

    Args:
    data (list): Die Daten, auf denen das Modell evaluiert werden soll.
    model_name (str): Der Name des Modells, das evaluiert werden soll.

    Returns:
    results (list): Eine Liste von Worterbüchern, die die Originalsätze, die vorhergesagten Token und die korrekten Antworten enthalten.
    """

    results = []
    for item in data:
        # Extract the question stem and choices from the item
        stem = item['question']['stem'].replace('[MASK]', tokenizer.mask_token)
        choices = [choice['text'] for choice in item['question']['choices']]

        # Predict the masked token
        predicted_token = predict_masked_token(model, tokenizer, stem, choices)

        # Find the correct answer based on the 'answerKey'
        correct_answer = [choice['text'] for choice in item['question']['choices'] if choice['label'] == item['answerKey']][0]

        # Add the results to the results list
        results.append({
            'id': item['id'],
            'original_sentence': item['question']['stem'],
            'predicted_token': predicted_token,
            'correct_answer': correct_answer
        })
    return results



def interpret_results(results):
    """
    Interpretieren von Ergebnissen der Modellbewertung.

    Args:
    results (list): Die Ergebnisse der Modellbewertung.

    Returns:
    None
    """
    for result in results:
        print(f"Original sentence: {result['original_sentence']}")
        print(f"Predicted token: {result['predicted_token']}")
        print(f"Correct answer: {result['correct_answer']}")
        print("Correct!" if result['predicted_token'] == result['correct_answer'] else "Incorrect!")
        print("------------------------")

def scores_results(results):
    """
    Gibt Accuracy aus.

    Args:
    results (list): Eine Liste von Wörterbüchern, die die Originalsätze, die vorhergesagten Token und die korrekten Antworten enthalten.

    Returns:
    None
    """
    correct = 0
    total = len(results)

    for result in results:
        if result['predicted_token'] == result['correct_answer']:
            correct += 1

    print(f"Accuracy: {correct / total * 100:.2f}%")

# %%
# Laden Modelle
tokenizer_roberta, model_roberta = load_model_and_tokenizer("roberta-base")
tokenizer_bert, model_bert = load_model_and_tokenizer("bert-base-cased")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# C:\Users\morit\miniconda3\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\morit\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Laden der Daten
always_never_data = load_data("data/challenge_coffee_cats_quantifiers_coffee_cats_quantifiers_dev.jsonl")
age_comparison_data = load_data("data/challenge_number_comparison_number_comparison_age_compare_masked_train.jsonl")

# %%
# Evaluieren und Interpretieren von Ergebnissen für das Roberta-Modell
print("Testing roberta-base on always_never data")
results_1 = evaluate_model(always_never_data,tokenizer_roberta,model_roberta)
interpret_results(results_1)

print("Testing roberta-base on age_comparison data")
results_2 = evaluate_model(age_comparison_data, tokenizer_roberta,model_roberta)
interpret_results(results_2)


# Evaluieren und Interpretieren von Ergebnisse für das BERT-Modell
print("Testing bert-base-cased on always_never data")
results_3 = evaluate_model(always_never_data, tokenizer_bert, model_bert)
interpret_results(results_3)

print("Testing bert-base-cased on age_comparison data")
results_4 = evaluate_model(age_comparison_data, tokenizer_bert, model_bert)
interpret_results(results_4)
# Out:
# Testing roberta-base on always_never data
# Original sentence: A robin [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A canine [MASK] has a jaw .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A ape [MASK] has a neck .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with cheese [MASK] contains honey .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A badger [MASK] has a snout .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: hammock is [MASK] placed in the corner .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A ostrich [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A insectivore [MASK] has a tail .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A lizard [MASK] has a wing .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with pasta [MASK] contains rice .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A worm [MASK] has a tongue .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: beef is [MASK] part of a canine's diet .
# Predicted token: often
# Correct answer: often
# Correct!
# ------------------------
# Original sentence: bed is [MASK] placed in the middle .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains fish .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains some vegetable .
# Predicted token: often
# Correct answer: often
# Correct!
# ------------------------
# Original sentence: A dish with chocolate [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: fish is [MASK] part of a rhea's diet .
# Predicted token: never
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A pig is [MASK] larger than a hare .
# Predicted token: never
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A hawk [MASK] has a beak .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: fish is [MASK] part of a male's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A leopard [MASK] has a tooth .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A beaver is [MASK] larger than a calf .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A lynx is [MASK] larger than a bat .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A calf is [MASK] larger than a horse .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A albatross is [MASK] larger than a vulture .
# Predicted token: sometimes
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A rat is [MASK] larger than a sheep .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A beaver [MASK] has a leg .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: chocolate is [MASK] part of a leopard's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A ape is [MASK] larger than a chicken .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains some garlic .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A badger [MASK] has a beard .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with cereal [MASK] contains rice .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A rat [MASK] has a leg .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A mink is [MASK] smaller than a coyote .
# Predicted token: often
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A calf is [MASK] larger than a bull .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A darter is [MASK] smaller than a worm .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A horse [MASK] has a back .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A stunt is [MASK] larger than a bear .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: chicken is [MASK] part of a feeder's diet .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with egg [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with loaf [MASK] contains wine .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: popcorn is [MASK] part of a puppy's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with soup [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with butter [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A turtle [MASK] has a belly .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: meat is [MASK] part of a pig's diet .
# Predicted token: never
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A dish with cheese [MASK] contains meat .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A pig is [MASK] smaller than a cat .
# Predicted token: always
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: buffet is [MASK] placed in the bathroom .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: fish is [MASK] part of a robin's diet .
# Predicted token: never
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with banana [MASK] contains some rice .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A leopard is [MASK] smaller than a panther .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A emu [MASK] has a beard .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: buffet is [MASK] placed in the corner .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: hammock is [MASK] placed in the room .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A blowfish [MASK] has a tongue .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A rabbit is [MASK] smaller than a lion .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: bed is [MASK] placed in the chamber .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with ham [MASK] contains fish .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: tuna is [MASK] part of a octopus's diet .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with potato [MASK] contains wine .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A lynx is [MASK] larger than a bear .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dolphin [MASK] has a neck .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A ape [MASK] has a spine .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains some milk .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: bread is [MASK] part of a pig's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A fowl is [MASK] larger than a chicken .
# Predicted token: never
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A dish with chicken [MASK] contains fish .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with butter [MASK] contains wine .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with coconut [MASK] contains butter .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: cheese is [MASK] part of a badger's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A eel is [MASK] smaller than a fish .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A bat is [MASK] larger than a coyote .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A squirrel is [MASK] larger than a fox .
# Predicted token: sometimes
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A mouse is [MASK] larger than a pig .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with fish [MASK] contains honey .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: sugar is [MASK] part of a mouse's diet .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A raccoon is [MASK] larger than a dog .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A insect is [MASK] larger than a wolf .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A bird is [MASK] larger than a mouse .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A eel is [MASK] larger than a crab .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a thoroughbred's diet .
# Predicted token: never
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A octopus [MASK] has a nose .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A horse [MASK] has a neck .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A walleye [MASK] has a nose .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A badger [MASK] has a tongue .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A fox is [MASK] larger than a leopard .
# Predicted token: sometimes
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A bear is [MASK] larger than a dog .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: prey is [MASK] part of a predator's diet .
# Predicted token: often
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A horse [MASK] has a leg .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: meat is [MASK] part of a elephant's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A herring is [MASK] larger than a carp .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A eel is [MASK] smaller than a wolf .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: lamp is [MASK] placed in the middle .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A cat is [MASK] larger than a mouse .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with tea [MASK] contains some cream .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with foodstuff [MASK] contains rice .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A pig [MASK] has a nose .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: bench is [MASK] placed in the middle .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with egg [MASK] contains fish .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A calf [MASK] has a belly .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: hammock is [MASK] placed in the centre .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A bear [MASK] has a horn .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with banana [MASK] contains some beef .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with soup [MASK] contains cheese .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with soup [MASK] contains wine .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with wine [MASK] contains honey .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A insect is [MASK] smaller than a rabbit .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: lamp is [MASK] placed in the room .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A dish with coconut [MASK] contains rum .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with meat [MASK] contains butter .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with fish [MASK] contains squid .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A rat [MASK] has a gut .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with loaf [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: stool is [MASK] placed in the box .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A yak [MASK] has a nose .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with beef [MASK] contains bacon .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with banana [MASK] contains some honey .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A mouse is [MASK] smaller than a frog .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: wardrobe is [MASK] placed in the box .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A bird is [MASK] larger than a duck .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with tea [MASK] contains some coffee .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: milk is [MASK] part of a yearling's diet .
# Predicted token: often
# Correct answer: often
# Correct!
# ------------------------
# Original sentence: A dish with ham [MASK] contains honey .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A ferret is [MASK] larger than a bear .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A hare is [MASK] larger than a leopard .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A rabbit [MASK] has a leg .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A ferret is [MASK] smaller than a dog .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A hare is [MASK] larger than a frog .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: milk is [MASK] part of a cat's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with cornflakes [MASK] contains some egg .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A monkey is [MASK] larger than a mouse .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: fur is [MASK] part of a rat's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with egg [MASK] contains cheese .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A calf is [MASK] smaller than a doe .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with slop [MASK] contains fish .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with cornflakes [MASK] contains some milk .
# Predicted token: often
# Correct answer: often
# Correct!
# ------------------------
# Original sentence: fur is [MASK] part of a ferret's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A omnivore [MASK] has a tooth .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: chair is [MASK] placed in the middle .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with vegetable [MASK] contains fish .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: prey is [MASK] part of a bat's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A bull [MASK] has a nose .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with fish [MASK] contains some soup .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with sausage [MASK] contains bacon .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A darter [MASK] has a tail .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a lion's diet .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A raccoon [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A fish [MASK] has a spine .
# Predicted token: sometimes
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: fur is [MASK] part of a rabbit's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: buffet is [MASK] placed in the center .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A tiger [MASK] has a spine .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: fat is [MASK] part of a raccoon's diet .
# Predicted token: never
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A dish with beans [MASK] contains some soup .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with cheese [MASK] contains bacon .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A calf is [MASK] larger than a dog .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A mink [MASK] has a tail .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A elephant is [MASK] larger than a mule .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with vegetable [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A rhea is [MASK] larger than a giant .
# Predicted token: never
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: honey is [MASK] part of a ape's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A rat [MASK] has a tail .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: milk is [MASK] part of a raccoon's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with lobster [MASK] contains bacon .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A tiger is [MASK] larger than a bird .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A elephant is [MASK] larger than a donkey .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with tea [MASK] contains some honey .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a eel's diet .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with lobster [MASK] contains shrimp .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A monkey [MASK] has a tongue .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: milk is [MASK] part of a migrator's diet .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A bat is [MASK] larger than a wolf .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with potato [MASK] contains pork .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: pork is [MASK] part of a rhea's diet .
# Predicted token: never
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with honey [MASK] contains vanilla .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with foodstuff [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A walleye is [MASK] larger than a cod .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A feeder [MASK] has a tail .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A fowl is [MASK] larger than a goose .
# Predicted token: never
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A dish with hamburger [MASK] contains pork .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with garlic [MASK] contains some beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with banana [MASK] contains some chocolate .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: venom is [MASK] part of a lynx's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with wine [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A elephant [MASK] has a nose .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A hawk [MASK] has a leg .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A bull [MASK] has a tail .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a crow's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A walleye [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A turtle [MASK] has a spine .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A crow [MASK] has a leg .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with milk [MASK] contains some cream .
# Predicted token: often
# Correct answer: often
# Correct!
# ------------------------
# Original sentence: A vulture [MASK] has a nose .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A mink [MASK] has a tongue .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with garlic [MASK] contains some chicken .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with pabulum [MASK] contains cream .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A prey [MASK] has a spine .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with tune [MASK] contains some sugar .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A leopard is [MASK] larger than a mouse .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A lizard [MASK] has a horn .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: bench is [MASK] placed in the garden .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A lynx is [MASK] larger than a panther .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A ape is [MASK] larger than a bird .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A mouse [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A tiger is [MASK] smaller than a horse .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A goose is [MASK] smaller than a partridge .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with wine [MASK] contains sugar .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A worm is [MASK] larger than a horse .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: fur is [MASK] part of a lion's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with garlic [MASK] contains some tomato .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: beef is [MASK] part of a walleye's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: dresser is [MASK] placed in the middle .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A walleye is [MASK] smaller than a carp .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A dish with yolk [MASK] contains egg .
# Predicted token: often
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: shell is [MASK] part of a crab's diet .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A eel is [MASK] smaller than a beetle .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: fur is [MASK] part of a leopard's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A insectivore [MASK] has a wing .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A nightingale [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with loaf [MASK] contains butter .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with egg [MASK] contains pork .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: herring is [MASK] part of a fish's diet .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A ostrich [MASK] has a foot .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with pasta [MASK] contains pork .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A vulture [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A monkey is [MASK] smaller than a lion .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A hawk is [MASK] larger than a bat .
# Predicted token: sometimes
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A dish with salmon [MASK] contains shrimp .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with hamburger [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with potato [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with vegetable [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A squirrel [MASK] has a nose .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: fur is [MASK] part of a squirrel's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with banana [MASK] contains some milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A primate [MASK] has a tail .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A beaver [MASK] has a belly .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: bench is [MASK] placed in the place .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A bear is [MASK] larger than a cow .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: fish is [MASK] part of a yak's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: table is [MASK] placed in the hall .
# Predicted token: always
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: beef is [MASK] part of a emu's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A dish with loaf [MASK] contains meat .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: tea is [MASK] part of a yak's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: fish is [MASK] part of a badger's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A crow is [MASK] larger than a squirrel .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A dish with cornflakes [MASK] contains some bacon .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A eagle is [MASK] larger than a sparrow .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a wolf's diet .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with cornflakes [MASK] contains some cereal .
# Predicted token: often
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A bullock is [MASK] larger than a mule .
# Predicted token: never
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A rabbit [MASK] has a spine .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A bat [MASK] has a horn .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: chair is [MASK] placed in the seat .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A spider is [MASK] larger than a rabbit .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A yak is [MASK] larger than a tiger .
# Predicted token: sometimes
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A bear is [MASK] larger than a cat .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with coconut [MASK] contains milk .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: meat is [MASK] part of a fowl's diet .
# Predicted token: never
# Correct answer: never
# Correct!
# ------------------------
# Original sentence: A herring [MASK] has a tail .
# Predicted token: sometimes
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A dish with tune [MASK] contains some honey .
# Predicted token: often
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A raccoon [MASK] has a tail .
# Predicted token: always
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: fat is [MASK] part of a lynx's diet .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A spider [MASK] has a wing .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with meat [MASK] contains beef .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A primate [MASK] has a spine .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A tiger is [MASK] larger than a donkey .
# Predicted token: sometimes
# Correct answer: often
# Incorrect!
# ------------------------
# Original sentence: A rat is [MASK] larger than a cow .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A nightingale is [MASK] larger than a bat .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A fish [MASK] has a tongue .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A beaver is [MASK] larger than a bull .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A pig [MASK] has a tail .
# Predicted token: never
# Correct answer: always
# Incorrect!
# ------------------------
# Original sentence: A raccoon is [MASK] larger than a beaver .
# Predicted token: sometimes
# Correct answer: sometimes
# Correct!
# ------------------------
# Original sentence: A canine [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A dish with wine [MASK] contains rice .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A squirrel is [MASK] smaller than a bear .
# Predicted token: always
# Correct answer: always
# Correct!
# ------------------------
# Original sentence: A dish with beans [MASK] contains some rice .
# Predicted token: often
# Correct answer: sometimes
# Incorrect!
# ------------------------
# Original sentence: A dish with salmon [MASK] contains beef .
# Predicted token: often
# Correct answer: rarely
# Incorrect!
# ------------------------
# Original sentence: A mouse is [MASK] larger than a coyote .
# Predicted token: sometimes
# Correct answer: never
# Incorrect!
# ------------------------
# Original sentence: A badger [MASK] has a horn .
# Predicted token: always
# Correct answer: never
# Incorrect!
# ------------------------
# Testing roberta-base on age_comparison data
# Original sentence: A 41 year old person age is [MASK] than a 42 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 43 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 44 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 45 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 46 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 47 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 48 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 49 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 50 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 51 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 52 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 53 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 54 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 55 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 56 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 57 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 58 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 59 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 60 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 61 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 62 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 63 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 64 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 65 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 66 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 67 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 68 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 69 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 70 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 71 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 72 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 73 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 74 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 75 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 76 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 77 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 78 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 79 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 80 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 81 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 82 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 83 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 84 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 85 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 86 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 87 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 88 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 89 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 90 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 91 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 92 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ------------------------
# Original sentence: A 41 year old person age is [MASK] than a 93 year old person .
# Predicted token: older
# Correct answer: younger
# Incorrect!
# ...
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 71 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 72 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 73 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 74 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 75 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 76 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 77 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 78 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 79 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 80 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 81 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 82 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 83 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 84 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 85 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 86 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 87 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 88 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 89 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 90 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 91 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 92 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 93 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 94 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 95 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 96 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 97 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 98 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 99 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 100 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 101 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 102 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 103 year old person age is [MASK] than a 104 year old person .
# Predicted token: younger
# Correct answer: younger
# Correct!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 41 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 42 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 43 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 44 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 45 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 46 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 47 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 48 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 49 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 50 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 51 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 52 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 53 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 54 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 55 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 56 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 57 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 58 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 59 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 60 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 61 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 62 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 63 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 64 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 65 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 66 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 67 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 68 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 69 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 70 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 71 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 72 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 73 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 74 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 75 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 76 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 77 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 78 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 79 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 80 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 81 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 82 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 83 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 84 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 85 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 86 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 87 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 88 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 89 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 90 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 91 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 92 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 93 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 94 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 95 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 96 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 97 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 98 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 99 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 100 year old person .
# Predicted token: older
# Correct answer: older
# Correct!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 101 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 102 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------
# Original sentence: A 104 year old person age is [MASK] than a 103 year old person .
# Predicted token: younger
# Correct answer: older
# Incorrect!
# ------------------------

# %%
print(f"for always_never data using roberta-base {scores_results(results_1)}\n")

print(f"for age_comparison data using roberta-base {scores_results(results_2)}\n")

print(f"for always_never data using bert-base-cased {scores_results(results_3)}\n")

print(f"for age_comparison data using bert-base-cased {scores_results(results_4)}\n")
# Out:
# Accuracy: 23.21%
# for always_never data using roberta-base None
#
# Accuracy: 50.00%
# for age_comparison data using roberta-base None
#
# Accuracy: 22.14%
# for always_never data using bert-base-cased None
#
# Accuracy: 50.17%
# for age_comparison data using bert-base-cased None

# %% [markdown]
# Like already stated in the oLMpics Test Paper, in the MC-MLM Test Setting, bert-base and robert-base Zero-Shot Encodings compute about the same Accuracy in the Test
